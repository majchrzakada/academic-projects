# %%
import numpy as np
import random
import scipy.stats as ss
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
from matplotlib import style

# %%
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.dpi'] = 150
style.use('seaborn')

# %% [markdown]
# # Basic threshold model

# %% [markdown]
# ## Time to consensus

# %%
def extract_data(graph, opinion0_prob):
    G = nx.number_of_nodes(graph)
    nodes = list(graph.nodes())
    opinion0_count = int(opinion0_prob*G)
    opinions = [-1]*opinion0_count + [1]*(G - opinion0_count)
    random.shuffle(opinions)
    neighbors = [0]*G
    for i in range(G):
        neighbors[i] = list(graph.neighbors(nodes[i]))
    return np.array(opinions), neighbors

# %%
def sym_to_consensus(graph, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    last_values = np.zeros(10000)
    data = extract_data(graph, opinion0_prob)
    opinions, neighbors = data
    len_opinions = len(opinions)
    
    step = 0
    while len(list(set(opinions))) == 2 and step < max_steps:
        nodes = np.random.randint(0, len_opinions, size=len_opinions)
        epsilons = np.random.uniform(size=len_opinions) < epsilon
        
        for i, node in enumerate(nodes):
            opinion = opinions[node]
            chosen_neighbors = random.sample(neighbors[node], k = q)
            chosen_opinions = opinions[chosen_neighbors]
            opposite_opinion = np.count_nonzero(chosen_opinions==-1*opinion)

            if opposite_opinion >= q0: 
                opinions[node] *= -1
            elif (epsilons[i] and opposite_opinion > 0):
                opinions[node] *= -1
                
        step += 1
        
    return step

# %%
def monte_carlo_sym_random(n, graph_prob, MC_steps, opinion0_prob, q, q0, epsilon, max_steps):
    mean_step = 0
    steps = 0
    counter = 0
    for i in range(MC_steps):
        g = nx.erdos_renyi_graph(n, graph_prob)
        while min(dict(g.degree()).values()) < q:
            g = nx.erdos_renyi_graph(n, graph_prob)
        steps = sym_to_consensus(g, opinion0_prob, q, q0, epsilon, max_steps)
        mean_step += steps
        if steps == max_steps:
            counter += 1
            if counter == 3:
                return 0
    return mean_step / MC_steps

# %%
def monte_carlo_sym_barabasi(n, barabasi_edges, MC_steps, opinion0_prob, q, q0, epsilon, max_steps):
    mean_step = 0
    steps = 0
    counter = 0
    for i in range(MC_steps):
        g = nx.barabasi_albert_graph(n, barabasi_edges)
        while min(dict(g.degree()).values()) < q:
            g = nx.barabasi_albert_graph(n, barabasi_edges)
        steps = sym_to_consensus(g, opinion0_prob, q, q0, epsilon, max_steps)
        mean_step += steps
        if steps == max_steps:
            counter += 1
            if counter == 3:
                print((0, i))
                return 0
    return mean_step / MC_steps

# %%
def monte_carlo_sym_watts(n, watts_edges, watts_prob, MC_steps, opinion0_prob, q, q0, epsilon, max_steps):
    mean_step = 0
    steps = 0
    counter = 0
    for i in range(MC_steps):
        g = nx.watts_strogatz_graph(n, watts_edges, watts_prob)
        while min(dict(g.degree()).values()) < q:
            g = nx.watts_strogatz_graph(n, watts_edges, watts_prob)
        steps += sym_to_consensus(g, opinion0_prob, q, q0, epsilon, max_steps)
        mean_step += steps
        if steps == max_steps:
            counter += 1
            if counter == 3:
                return 0
    return mean_step / MC_steps

# %%
def consensus_time_random(ns, graph_prob, epsilon, MC_steps, opinion0_prob, q, q0, max_steps = 10**4):
    mean_times = np.zeros(len(ns))
    for n in range(len(ns)):
        mean_times[n] = monte_carlo_sym_random(ns[n], graph_prob, MC_steps, opinion0_prob, q, q0, epsilon, max_steps)
        if mean_times[n] == 0:
            break
    return mean_times

# %%
def consensus_time_barabasi(ns, barabasi_edges, epsilon, MC_steps, opinion0_prob, q, q0, max_steps = 10**4):
    mean_times = np.zeros(len(ns))
    for n in range(len(ns)):
        mean_times[n] = monte_carlo_sym_barabasi(ns[n], barabasi_edges, MC_steps, opinion0_prob, q, q0, epsilon, max_steps)
        if mean_times[n] == 0:
            break
    return mean_times

# %%
def consensus_time_watts(ns, watts_edges, watts_prob, epsilon, MC_steps, opinion0_prob, q, q0, max_steps = 10**4):
    mean_times = np.zeros(len(ns))
    for n in range(len(ns)):
        mean_times[n] = monte_carlo_sym_watts(ns[n], watts_edges, watts_prob, MC_steps, opinion0_prob, q, q0, epsilon, max_steps)
        if mean_times[n] == 0:
            break
    return mean_times

# %% [markdown]
# ### Barabasi

# %%
ns = np.arange(100, 2000, 200)
epsilons = np.arange(0.1, 0.5, 0.05)
q = 6
q0 = 6
MC_steps = 100
opinion0_prob = 0.5
barabasi_edges = 8

# %%
# %%time
l = []
for e in epsilons:
    print(e)
    l.append(consensus_time_barabasi(ns, barabasi_edges, e, MC_steps, opinion0_prob, q, q0, max_steps = 10**4))
# Out:
# 0.1
# (0, 90)
# 0.15000000000000002
# (0, 2)
# 0.20000000000000004
# (0, 2)
# 0.25000000000000006
# (0, 2)
# 0.30000000000000004
# (0, 2)
# 0.3500000000000001
# (0, 2)
# 0.40000000000000013
# (0, 2)
# 0.45000000000000007
# (0, 2)
# CPU times: total: 5min 26s
# Wall time: 6min 59s

# %%
df = pd.DataFrame(l, columns = ns)
df.to_csv(f'data/Barabasi_{q}_{q0}.csv')

# %%
for e in l:
    plt.plot(ns, e)
plt.legend(epsilons)
plt.title('Time to consensus as function of network size for BA(N, 8)')
plt.xlabel('N')
plt.ylabel('MCS')
plt.savefig(f'plots/Barabasi_consensus_{q}_{q0}.png')

# %% [markdown]
# ### Watts

# %%
ns = [100, 250, 500, 1000, 1500, 2000, 2500, 3000, 4000, 5000]
epsilons = np.arange(0.1, 0.45, 0.05)
q = 6
q0 = 6
MC_steps = 100
opinion0_prob = 0.5 
watts_edges, watts_prob = 12, 0.2

# %%
# %%time
l = []
for e in epsilons:
    print(e)
    l.append(consensus_time_watts(ns, watts_edges, watts_prob, e, MC_steps, opinion0_prob, q, q0, max_steps = 10**4))
# Out:
# 0.1

# %%
df = pd.DataFrame(l, columns = ns)
df.to_csv(f'data/Watts_{q}_{q0}.csv')

# %%
for e in l:
    plt.plot(ns, e)
plt.legend(epsilons)
plt.title('Time to consensus as function of network size for WS(N, 12, 0.2)')
plt.xlabel('N')
plt.ylabel('MCS')
plt.savefig(f'plots/Watts_consensus_{q}_{q0}.png')

# %% [markdown]
# ### Random

# %%
ns = [100, 250, 500, 1000, 1500, 2000, 2500, 3000, 4000, 5000]
epsilons = np.arange(0.1, 0.45, 0.05)
q = 6
q0 = 6
MC_steps = 100
opinion0_prob = 0.5 
graph_prob = 0.12

# %%
# %%time
l = []
for e in epsilons:
    print(e)
    l.append(consensus_time_random(ns, graph_prob, e, MC_steps, opinion0_prob, q, q0, max_steps = 10**4))

# %%
df = pd.DataFrame(l, columns = ns)
df.to_csv(f'data/Random_{q}_{q0}.csv')

# %%
for e in l:
    plt.plot(ns, e)
plt.legend(epsilons)
plt.title('Time to consensus as function of network size for RG(N, 0.12)')
plt.xlabel('N')
plt.ylabel('MCS')
plt.savefig(f'plots/Random_consensus_{q}_{q0}.png')

# %% [markdown]
# ### Random fully connected

# %%
ns = [100, 250, 500, 1000, 1500, 2000, 2500, 3000, 4000, 5000]
epsilons = np.arange(0.1, 0.45, 0.05)
q = 6
q0 = 6
MC_steps = 100
opinion0_prob = 0.5 
graph_prob = 1

# %%
# %%time
l = []
for e in epsilons:
    print(e)
    l.append(consensus_time_random(ns, graph_prob, e, MC_steps, opinion0_prob, q, q0, max_steps = 10**4))

# %%
df = pd.DataFrame(l, columns = ns)
df.to_csv(f'data/Random_connected_{q}_{q0}.csv')

# %%
for e in l:
    plt.plot(ns, e)
plt.legend(epsilons)
plt.title('Time to consensus as function of network size for RG(N, 1)')
plt.xlabel('N')
plt.ylabel('MCS')
plt.savefig(f'plots/Random_connected_consensus_{q}_{q0}.png')

# %% [markdown]
# ## Magnetization

# %% [markdown]
# ## Concentration

# %%
def sym_data(graph, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    last_values = np.zeros(10000)
    data = extract_data(graph, opinion0_prob)
    opinions, neighbors = data
    len_opinions = len(opinions)
    magnetization = np.zeros(max_steps)
    step = 0
    while len(list(set(opinions))) == 2 and step < max_steps:
        nodes = np.random.randint(0, len_opinions, size=len_opinions)
        epsilons = np.random.uniform(size=len_opinions) < epsilon
        
        for i, node in enumerate(nodes):
            opinion = opinions[node]
            chosen_neighbors = random.sample(neighbors[node], k = q)
            chosen_opinions = opinions[chosen_neighbors]
            opposite_opinion = np.count_nonzero(chosen_opinions==-1*opinion)

            if opposite_opinion >= q0: 
                opinions[node] *= -1
            elif (epsilons[i] and opposite_opinion > 0):
                opinions[node] *= -1
                
        magnetization[step] = np.sum(opinions)/len_opinions        
        step += 1
    
    magnetization[step:] = magnetization[step - 1]
        
    concentration = np.count_nonzero(opinions==-1)/len_opinions
    concentration_win = concentration if concentration >= 0.5 else 1-concentration
    
    return magnetization, concentration_win

# %%
def avg_magn_conc_random(N, graph_prob, MCsteps, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    magn_results = np.zeros((MCsteps, max_steps))
    conc_results = np.zeros(MCsteps)
    for i in range(MCsteps):
        g = nx.erdos_renyi_graph(N, graph_prob)
        while min(dict(g.degree()).values()) < q:
            g = nx.erdos_renyi_graph(N, graph_prob)
        r_m, r_c = sym_data(g, opinion0_prob, q, q0, epsilon, max_steps)
        magn_results[i] = abs(r_m)
        conc_results[i] = r_c
    return np.mean(magn_results, axis = 0), np.mean(conc_results)

# %%
def avg_magn_conc_barabasi(N, barabasi_edges, MCsteps, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    magn_results = np.zeros((MCsteps, max_steps))
    conc_results = np.zeros(MCsteps)
    for i in range(MCsteps):
        g = nx.barabasi_albert_graph(N, barabasi_edges)
        while min(dict(g.degree()).values()) < q:
            g = nx.barabasi_albert_graph(N, barabasi_edges)
        r_m, r_c = sym_data(g, opinion0_prob, q, q0, epsilon, max_steps)
        magn_results[i] = abs(r_m)
        conc_results[i] = r_c
    return np.mean(magn_results, axis = 0), np.mean(conc_results)

# %%
def avg_magn_conc_watts(N, watts_edges, watts_prob, MCsteps, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    magn_results = np.zeros((MCsteps, max_steps))
    conc_results = np.zeros(MCsteps)
    for i in range(MCsteps):
        g = nx.watts_strogatz_graph(N, watts_edges, watts_prob)
        while min(dict(g.degree()).values()) < q:
            g = nx.watts_strogatz_graph(N, watts_edges, watts_prob)
        r_m, r_c = sym_data(g, opinion0_prob, q, q0, epsilon, max_steps)
        magn_results[i] = abs(r_m)
        conc_results[i] = r_c
    return np.mean(magn_results, axis = 0), np.mean(conc_results)

# %%
# epsilons = np.arange(0.1, 0.45, 0.05)
epsilons = np.arange(0.12, 0.5, 0.05)
eps_column = [fr'$\epsilon={round(e, 2)}$' for e in epsilons]
q = 6
#q0 = 3   # - babka
q0 = 4   # - matka
op1 = 0.5
N = 200
MCsteps = 100
max_steps = 10**4

# %% [markdown]
# ## Random

# %%
rg_prob = 0.12

# %%
conc_eps = np.zeros(len(epsilons))
magn_eps = np.zeros((len(epsilons), max_steps))
magn_last = np.zeros(len(epsilons))
for i, e in enumerate(epsilons):
    magn_eps[i], conc_eps[i] = avg_magn_conc_random(N, rg_prob, MCsteps, op1, q, q0, e, max_steps)
    magn_last[i] = magn_eps[i][-1]

# %%
contrary_conc = 1 - conc_eps

# %%
df_c = pd.DataFrame(conc_eps)
df_c = df_c.transpose()
df_c.columns = eps_column
df_c.to_csv(f'data/conc_random_{q}_{q0}b.csv', index=False)

# %%
df_m = pd.DataFrame(magn_eps)
df_m = df_m.transpose()
df_m.columns = eps_column
df_m.to_csv(f'data/magn_random_{q}_{q0}b.csv', index=False)

# %%
plt.plot(epsilons, conc_eps)
plt.plot(epsilons, contrary_conc)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Concentration')
plt.title(fr"Final concentration as a function of $\epsilon$ for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/conc_random_{q}_{q0}b.png")

# %%
plt.plot(epsilons, magn_last)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Magnetization')
plt.title(fr"Final magnetization as a function of $\epsilon$ for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/magn_last_random_{q}_{q0}b.png")

# %%
for i, e in enumerate(epsilons):
    plt.plot(range(max_steps), magn_eps[i], label=fr"$\epsilon = {e}$")
plt.xlabel(r'MCS')
plt.ylabel('Magnetization')
plt.legend()
plt.title(fr"Magnetization in time $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/magn_random_{q}_{q0}b.png")

# %% [markdown]
# ## Fully connected

# %%
rg_prob = 1

# %%
conc_eps = np.zeros(len(epsilons))
magn_eps = np.zeros((len(epsilons), max_steps))
magn_last = np.zeros(len(epsilons))
for i, e in enumerate(epsilons):
    magn_eps[i], conc_eps[i] = avg_magn_conc_random(N, rg_prob, MCsteps, op1, q, q0, e, max_steps)
    magn_last[i] = magn_eps[i][-1]

# %%
contrary_conc = 1 - conc_eps

# %%
df_c = pd.DataFrame(conc_eps)
df_c = df_c.transpose()
df_c.columns = eps_column
df_c.to_csv(f'data/conc_connected_{q}_{q0}b.csv', index=False)

# %%
df_m = pd.DataFrame(magn_eps)
df_m = df_m.transpose()
df_m.columns = eps_column
df_m.to_csv(f'data/magn_connected_{q}_{q0}b.csv', index=False)

# %%
plt.plot(epsilons, conc_eps)
plt.plot(epsilons, contrary_conc)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Concentration')
plt.title(fr"Final concentration as a function of $\epsilon$ for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/conc_connected_{q}_{q0}b.png")

# %%
plt.plot(epsilons, magn_last)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Magnetization')
plt.title(fr"Final magnetization as a function of $\epsilon$ for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/magn_last_connected_{q}_{q0}b.png")

# %%
for i, e in enumerate(epsilons):
    plt.plot(range(max_steps), magn_eps[i], label=fr"$\epsilon = {e}$")
plt.xlabel(r'MCS')
plt.ylabel('Magnetization')
plt.legend()
plt.title(fr"Magnetization in time for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/magn_connected_{q}_{q0}b.png")

# %% [markdown]
# ## Barabasi

# %%
barabasi_edges = 8

# %%
conc_eps = np.zeros(len(epsilons))
magn_eps = np.zeros((len(epsilons), max_steps))
magn_last = np.zeros(len(epsilons))
for i, e in enumerate(epsilons):
    magn_eps[i], conc_eps[i] = avg_magn_conc_barabasi(N, barabasi_edges, MCsteps, op1, q, q0, e, max_steps)
    magn_last[i] = magn_eps[i][-1]

# %%
contrary_conc = 1 - conc_eps

# %%
df_c = pd.DataFrame(conc_eps)
df_c = df_c.transpose()
df_c.columns = eps_column
df_c.to_csv(f'data/conc_barabasi_{q}_{q0}b.csv', index=False)

# %%
df_m = pd.DataFrame(magn_eps)
df_m = df_m.transpose()
df_m.columns = eps_column
df_m.to_csv(f'data/magn_barabasi_{q}_{q0}b.csv', index=False)

# %%
plt.plot(epsilons, conc_eps)
plt.plot(epsilons, contrary_conc)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Concentration')
plt.title(fr"Final concentration as a function of $\epsilon$ for $BA({N}, {barabasi_edges})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/conc_barabasi_{q}_{q0}b.png")

# %%
plt.plot(epsilons, magn_last)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Magnetization')
plt.title(fr"Final magnetization as a function of $\epsilon$ for $BA({N}, {barabasi_edges})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/magn_last_barabasi_{q}_{q0}b.png")

# %%
for i, e in enumerate(epsilons):
    plt.plot(range(max_steps), magn_eps[i], label=fr"$\epsilon = {e}$")
plt.xlabel(r'MCS')
plt.ylabel('Magnetization')
plt.legend()
plt.title(fr"Magnetization in time for $BA({N}, {barabasi_edges})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/magn_barabasi_{q}_{q0}b.png")

# %% [markdown]
# ## Watts

# %%
watts_edges = 12
watts_prob = 0.2

# %%
conc_eps = np.zeros(len(epsilons))
magn_eps = np.zeros((len(epsilons), max_steps))
magn_last = np.zeros(len(epsilons))
for i, e in enumerate(epsilons):
    magn_eps[i], conc_eps[i] = avg_magn_conc_watts(N, watts_edges, watts_prob, MCsteps, op1, q, q0, e, max_steps)
    magn_last[i] = magn_eps[i][-1]

# %%
contrary_conc = 1 - conc_eps

# %%
df_c = pd.DataFrame(conc_eps)
df_c = df_c.transpose()
df_c.columns = eps_column
df_c.to_csv(f'data/conc_watts_{q}_{q0}b.csv', index=False)

# %%
df_m = pd.DataFrame(magn_eps)
df_m = df_m.transpose()
df_m.columns = eps_column
df_m.to_csv(f'data/magn_watts_{q}_{q0}b.csv', index=False)

# %%
plt.plot(epsilons, conc_eps)
plt.plot(epsilons, contrary_conc)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Concentration')
plt.title(fr"Final concentration as a function of $\epsilon$ for $WS({N}, {watts_edges}, {watts_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/conc_watts_{q}_{q0}b.png")

# %%
plt.plot(epsilons, magn_last)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Magnetization')
plt.title(fr"Final magnetization as a function of $\epsilon$ for $WS({N}, {watts_edges}, {watts_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/magn_last_watts_{q}_{q0}b.png")

# %%
for i, e in enumerate(epsilons):
    plt.plot(range(max_steps), magn_eps[i], label=fr"$\epsilon = {e}$")
plt.xlabel(r'MCS')
plt.ylabel('Magnetization')
plt.legend()
plt.title(fr"Magnetization in time for $WS({N}, {watts_edges}, {watts_prob})$, $q = {q}$, $q_0 = {q0}$")
plt.savefig(f"data/magn_watts_{q}_{q0}b.png")

# %% [markdown]
# # Our modification

# %% [markdown]
# ## Time to consensus

# %%
def extract_data_common(graph, opinion0_prob):
    G = nx.number_of_nodes(graph)
    nodes = list(graph.nodes())
    opinion0_count = int(opinion0_prob*G)
    opinions = [-1]*opinion0_count + [1]*(G - opinion0_count)
    random.shuffle(opinions)
    neighbors = [0]*G
    common = np.zeros((G, G))
    for i in range(G):
        neighbors[i] = list(graph.neighbors(nodes[i]))
    for i in range(G):
        for j in range(G):
            common[i][j] = len(set(neighbors[i]) & set(neighbors[j]))
    return np.array(opinions), neighbors, common

# %%
def sym_to_consensus_common(graph, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    opinions, neighbors, common = extract_data_common(graph, opinion0_prob)
    len_opinions = len(opinions)
    step = 0
    while len(list(set(opinions))) == 2 and step < max_steps:
        chosen = np.random.randint(0, len_opinions)
        opinion = opinions[chosen]
        chosen_neighbors = random.sample(neighbors[chosen], k = q)
        chosen_opinions = np.array([opinions[i] for i in chosen_neighbors])
        chosen_common = [common[chosen, i] for i in chosen_neighbors]
        opposite_inds = np.where(chosen_opinions == -1*opinion)[0]
        opposite_opinion = np.sum([chosen_common[i] for i in opposite_inds]) / np.sum(chosen_common) \
            if np.sum(chosen_common) > 0 else 0
        
        if opposite_opinion > q0 or (epsilon > np.random.uniform() and opposite_opinion > 0):
            opinions[chosen] *= -1
        step += 1
        
    return step

# %%
def monte_carlo_sym_random_common(n, graph_prob, MC_steps, opinion0_prob, q, q0, epsilon, max_steps):
    mean_step = 0
    steps = 0
    counter = 0
    for i in range(MC_steps):
        g = nx.erdos_renyi_graph(n, graph_prob)
        while min(dict(g.degree()).values()) < q:
            g = nx.erdos_renyi_graph(n, graph_prob)
        steps = sym_to_consensus_common(g, opinion0_prob, q, q0, epsilon, max_steps)
        mean_step += steps
        if steps == max_steps:
            counter += 1
            if counter == 3:
                return 0
    return mean_step / MC_steps

# %%
def monte_carlo_sym_barabasi_common(n, barabasi_edges, MC_steps, opinion0_prob, q, q0, epsilon, max_steps):
    mean_step = 0
    steps = 0
    counter = 0
    for i in range(MC_steps):
        g = nx.barabasi_albert_graph(n, barabasi_edges)
        while min(dict(g.degree()).values()) < q:
            g = nx.barabasi_albert_graph(N, barabasi_edges)
        steps = sym_to_consensus_common(g, opinion0_prob, q, q0, epsilon, max_steps)
        mean_step += steps
        if steps == max_steps:
            counter += 1
            if counter == 3:
                print((0, i))
                return 0
    return mean_step / MC_steps

# %%
def monte_carlo_sym_watts_common(n, watts_edges, watts_prob, MC_steps, opinion0_prob, q, q0, epsilon, max_steps):
    mean_step = 0
    steps = 0
    counter = 0
    for i in range(MC_steps):
        g = nx.watts_strogatz_graph(n, watts_edges, watts_prob)
        while min(dict(g.degree()).values()) < q:
            g = nx.watts_strogatz_graph(n, watts_edges, watts_prob)
        steps = sym_to_consensus_common(g, opinion0_prob, q, q0, epsilon, max_steps)
        mean_step += steps
        if steps == max_steps:
            counter += 1
            if counter == 3:
                return 0
    return mean_step / MC_steps

# %%
def consensus_time_random_common(ns, graph_prob, epsilon, MC_steps, opinion0_prob, q, q0, max_steps = 10**4):
    mean_times = np.zeros(len(ns))
    for n in range(len(ns)):
        print(ns[n])
        mean_times[n] = monte_carlo_sym_random_common(ns[n], graph_prob, MC_steps, opinion0_prob, q, q0, epsilon, max_steps)
    return mean_times

# %%
def consensus_time_barabasi_common(ns, barabasi_edges, epsilon, MC_steps, opinion0_prob, q, q0, max_steps = 10**4):
    mean_times = np.zeros(len(ns))
    for n in range(len(ns)):
        print(ns[n])
        mean_times[n] = monte_carlo_sym_barabasi_common(ns[n], barabasi_edges, MC_steps, opinion0_prob, q, q0, epsilon, max_steps)
    return mean_times

# %%
def consensus_time_watts_common(ns, watts_edges, watts_prob, epsilon, MC_steps, opinion0_prob, q, q0, max_steps = 10**4):
    mean_times = np.zeros(len(ns))
    for n in range(len(ns)):
        print(ns[n])
        mean_times[n] = monte_carlo_sym_watts_common(ns[n], watts_edges, watts_prob, MC_steps, opinion0_prob, q, q0, epsilon, max_steps)
    return mean_times

# %% [markdown]
# ## Magnetization

# %%
def sym_data_common(graph, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    opinions, neighbors, common = extract_data_common(graph, opinion0_prob)
    len_opinions = len(opinions)
    step = 0
    magnetization = np.zeros(max_steps)
    
    while len(list(set(opinions))) == 2 and step < max_steps:
        nodes = np.random.randint(0, len_opinions, size=len_opinions)
        epsilons = np.random.uniform(size=len_opinions) < epsilon
        
        for i, chosen in enumerate(nodes):
        
            #chosen = np.random.randint(0, len_opinions)
            opinion = opinions[chosen]
            chosen_neighbors = random.sample(neighbors[chosen], k = q)
            chosen_opinions = np.array([opinions[i] for i in chosen_neighbors])
            chosen_common = [common[chosen, i] for i in chosen_neighbors]
            opposite_inds = np.where(chosen_opinions == -1*opinion)[0]
            sum_chosen = np.sum(chosen_common)
            opposite_opinion = np.sum([chosen_common[i] for i in opposite_inds]) / sum_chosen \
                if sum_chosen > 0 else 0
            if opposite_opinion > q0:
                opinions[chosen] *= -1
            elif (epsilons[i] and opposite_opinion > 0):
                opinions[chosen] *= -1
        magnetization[step] = np.sum(opinions)/len_opinions
        step += 1
    magnetization[step:] = magnetization[step - 1]
    
    concentration = np.count_nonzero(opinions==-1)/len_opinions
    concentration_win = concentration if concentration >= 0.5 else 1-concentration
    
    return magnetization, concentration_win

# %%
def avg_magn_conc_common_random(N, graph_prob, MCsteps, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    magn_results = np.zeros((MCsteps, max_steps))
    conc_results = np.zeros(MCsteps)
    for i in range(MCsteps):
        g = nx.erdos_renyi_graph(N, graph_prob)
        while min(dict(g.degree()).values()) < q:
            g = nx.erdos_renyi_graph(N, graph_prob)
        r_m, r_c = sym_data_common(g, opinion0_prob, q, q0, epsilon, max_steps)
        magn_results[i] = abs(r_m)
        conc_results[i] = r_c
    return np.mean(magn_results, axis = 0), np.mean(conc_results)

# %%
def avg_magn_conc_common_watts(N, watts_edges, watts_prob, MCsteps, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    magn_results = np.zeros((MCsteps, max_steps))
    conc_results = np.zeros(MCsteps)
    for i in range(MCsteps):
        g = nx.watts_strogatz_graph(N, watts_edges, watts_prob)
        while min(dict(g.degree()).values()) < q:
            g = nx.watts_strogatz_graph(N, watts_edges, watts_prob)
        r_m, r_c = sym_data_common(g, opinion0_prob, q, q0, epsilon, max_steps)
        magn_results[i] = abs(r_m)
        conc_results[i] = r_c
    return np.mean(magn_results, axis = 0), np.mean(conc_results)

# %%
def avg_magn_conc_common_barabasi(N, barabasi_edges, MCsteps, opinion0_prob, q, q0, epsilon, max_steps = 10**4):
    magn_results = np.zeros((MCsteps, max_steps))
    conc_results = np.zeros(MCsteps)
    for i in range(MCsteps):
        g = nx.barabasi_albert_graph(N, barabasi_edges)
        while min(dict(g.degree()).values()) < q:
            g = nx.barabasi_albert_graph(N, barabasi_edges)
        r_m, r_c = sym_data_common(g, opinion0_prob, q, q0, epsilon, max_steps)
        magn_results[i] = abs(r_m)
        conc_results[i] = r_c
    return np.mean(magn_results, axis = 0), np.mean(conc_results)

# %%
# epsilons = np.arange(0.1, 0.45, 0.05)
epsilons = np.arange(0.12, 0.5, 0.05)
eps_column = [fr'$\epsilon={round(e, 2)}$' for e in epsilons]
q = 6
q0 = 0.5
#q0 = 2/3
op1 = 0.5
N = 200
MCsteps = 100
max_steps = 10**4
#q00 = 4
q00 = 3

# %% [markdown]
# ## Connected

# %%
rg_prob = 1

# %%
conc_eps = np.zeros(len(epsilons))
magn_eps = np.zeros((len(epsilons), max_steps))
magn_last = np.zeros(len(epsilons))
for i, e in enumerate(epsilons):
    magn_eps[i], conc_eps[i] = avg_magn_conc_common_random(N, rg_prob, MCsteps, op1, q, q0, e, max_steps)
    magn_last[i] = magn_eps[i][-1]

# %%
contrary_conc = 1 - conc_eps

# %%
df_c = pd.DataFrame(conc_eps)
df_c = df_c.transpose()
df_c.columns = eps_column
df_c.to_csv(f'data/conc_common_connected_{q}_{q00}b.csv', index=False)

# %%
df_m = pd.DataFrame(magn_eps)
df_m = df_m.transpose()
df_m.columns = eps_column
df_m.to_csv(f'data/magn_common_connected_{q}_{q00}b.csv', index=False)

# %%
plt.plot(epsilons, conc_eps)
plt.plot(epsilons, contrary_conc)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Concentration')
plt.title(fr"Final concentration as a function of $\epsilon$ for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/conc_common_connected_{q}_{q00}b.png")

# %%
plt.plot(epsilons, magn_last)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Magnetization')
plt.title(fr"Final magnetization as a function of $\epsilon$ for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/magn_common_last_connected_{q}_{q00}b.png")

# %%
for i, e in enumerate(epsilons):
    plt.plot(range(max_steps), magn_eps[i], label=fr"$\epsilon = {e}$")
plt.xlabel(r'MCS')
plt.ylabel('Magnetization')
plt.legend()
plt.title(fr"Magnetization in time for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/magn_common_connected_{q}_{q00}b.png")

# %% [markdown]
# ## Random

# %%
rg_prob = 0.12

# %%
conc_eps = np.zeros(len(epsilons))
magn_eps = np.zeros((len(epsilons), max_steps))
magn_last = np.zeros(len(epsilons))
for i, e in enumerate(epsilons):
    magn_eps[i], conc_eps[i] = avg_magn_conc_common_random(N, rg_prob, MCsteps, op1, q, q0, e, max_steps)
    magn_last[i] = magn_eps[i][-1]

# %%
contrary_conc = 1 - conc_eps

# %%
df_c = pd.DataFrame(conc_eps)
df_c = df_c.transpose()
df_c.columns = eps_column
df_c.to_csv(f'data/conc_common_random_{q}_{q00}b.csv', index=False)

# %%
df_m = pd.DataFrame(magn_eps)
df_m = df_m.transpose()
df_m.columns = eps_column
df_m.to_csv(f'data/magn_common_random_{q}_{q00}b.csv', index=False)

# %%
plt.plot(epsilons, conc_eps)
plt.plot(epsilons, contrary_conc)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Concentration')
plt.title(fr"Final concentration as a function of $\epsilon$ for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/conc_common_random_{q}_{q00}b.png")

# %%
plt.plot(epsilons, magn_last)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Magnetization')
plt.title(fr"Final magnetization as a function of $\epsilon$ for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/magn_common_last_random_{q}_{q00}b.png")

# %%
for i, e in enumerate(epsilons):
    plt.plot(range(max_steps), magn_eps[i], label=fr"$\epsilon = {e}$")
plt.xlabel(r'MCS')
plt.ylabel('Magnetization')
plt.legend()
plt.title(fr"Magnetization in time for $RG({N}, {rg_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/magn_common_random_{q}_{q00}b.png")

# %% [markdown]
# ## Barabasi

# %%
barabasi_edges = 8

# %%
conc_eps = np.zeros(len(epsilons))
magn_eps = np.zeros((len(epsilons), max_steps))
magn_last = np.zeros(len(epsilons))
for i, e in enumerate(epsilons):
    magn_eps[i], conc_eps[i] = avg_magn_conc_common_random(N, barabasi_edges, MCsteps, op1, q, q0, e, max_steps)
    magn_last[i] = magn_eps[i][-1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-a258f8716092> in <module>
#       3 magn_last = np.zeros(len(epsilons))
#       4 for i, e in enumerate(epsilons):
# ----> 5     magn_eps[i], conc_eps[i] = avg_magn_conc_common_random(N, barabasi_edges, MCsteps, op1, q, q0, e, max_steps)
#       6     magn_last[i] = magn_eps[i][-1]
#
# <ipython-input-78-abe4883b56f3> in avg_magn_conc_common_random(N, graph_prob, MCsteps, opinion0_prob, q, q0, epsilon, max_steps)
#       6         while min(dict(g.degree()).values()) < q:
#       7             g = nx.erdos_renyi_graph(N, graph_prob)
# ----> 8         r_m, r_c = sym_data_common(g, opinion0_prob, q, q0, epsilon, max_steps)
#       9         magn_results[i] = abs(r_m)
#      10         conc_results[i] = r_c
#
# <ipython-input-77-00013a0ea31b> in sym_data_common(graph, opinion0_prob, q, q0, epsilon, max_steps)
# ...

# %%
contrary_conc = 1 - conc_eps

# %%
df_c = pd.DataFrame(conc_eps)
df_c = df_c.transpose()
df_c.columns = eps_column
df_c.to_csv(f'data/conc_common_barabasi_{q}_{q00}b.csv', index=False)

# %%
df_m = pd.DataFrame(magn_eps)
df_m = df_m.transpose()
df_m.columns = eps_column
df_m.to_csv(f'data/magn_common_barabasi_{q}_{q00}b.csv', index=False)

# %%
plt.plot(epsilons, conc_eps)
plt.plot(epsilons, contrary_conc)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Concentration')
plt.title(fr"Final concentration as a function of $\epsilon$ for $BA({N}, {barabasi_edges})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/conc_common_barabasi_{q}_{q00}b.png")

# %%
plt.plot(epsilons, magn_last)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Magnetization')
plt.title(fr"Final magnetization as a function of $\epsilon$ for graph name, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/magn_last_common_barabasi_{q}_{q00}b.png")

# %%
for i, e in enumerate(epsilons):
    plt.plot(range(max_steps), magn_eps[i], label=fr"$\epsilon = {e}$")
plt.xlabel(r'MCS')
plt.ylabel('Magnetization')
plt.legend()
plt.title(fr"Magnetization in time for graph name, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/magn_common_barabasi_{q}_{q00}b.png")

# %% [markdown]
# ## Watts

# %%
watts_edges = 12
watts_prob = 0.2

# %%
conc_eps = np.zeros(len(epsilons))
magn_eps = np.zeros((len(epsilons), max_steps))
magn_last = np.zeros(len(epsilons))
for i, e in enumerate(epsilons):
    magn_eps[i], conc_eps[i] = avg_magn_conc_common_watts(N, watts_edges, watts_prob, MCsteps, op1, q, q0, e, max_steps)
    magn_last[i] = magn_eps[i][-1]

# %%
contrary_conc = 1 - conc_eps

# %%
df_c = pd.DataFrame(conc_eps)
df_c = df_c.transpose()
df_c.columns = eps_column
df_c.to_csv(f'data/conc_common_watts_{q}_{q00}b.csv', index=False)

# %%
df_m = pd.DataFrame(magn_eps)
df_m = df_m.transpose()
df_m.columns = eps_column
df_m.to_csv(f'data/magn_common_watts_{q}_{q00}b.csv', index=False)

# %%
plt.plot(epsilons, conc_eps)
plt.plot(epsilons, contrary_conc)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Concentration')
plt.title(fr"Final concentration as a function of $\epsilon$ for $WS({N}, {watts_edges}, {watts_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/conc_common_watts_{q}_{q00}b.png")

# %%
plt.plot(epsilons, magn_last)
plt.xlabel(r'$\epsilon$')
plt.ylabel('Magnetization')
plt.title(fr"Final magnetization as a function of $\epsilon$ for $WS({N}, {watts_edges}, {watts_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/magn_last_common_watts_{q}_{q00}b.png")

# %%
for i, e in enumerate(epsilons):
    plt.plot(range(max_steps), magn_eps[i], label=fr"$\epsilon = {e}$")
plt.xlabel(r'MCS')
plt.ylabel('Magnetization')
plt.legend()
plt.title(fr"Magnetization in time for $WS({N}, {watts_edges}, {watts_prob})$, $q = {q}$, $q_0 = {q00}$")
plt.savefig(f"data/magn_common_watts_{q}_{q00}b.png")
